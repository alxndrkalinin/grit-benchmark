# %% [markdown]
# ## Reprocess Cell Health profiles
#
# Use a whole-plate normalization scheme instead of normalization by controls only.
#
# We will use the control normalization in downstream analyses, but we are interested in comparing the impact of normalization strategy on grit calculations.

# %%
import sys
import pathlib

from tqdm import tqdm
import pandas as pd

from pycytominer import normalize, feature_select

sys.path.append("scripts")
from normalization import sphere

# %%
def normalize_profile(plate, output_dir, commit="cd91bd0daacef2b5ea25dcceb62482bb664d9de1"):
    link = f"https://github.com/broadinstitute/cell-health/raw/{commit}/1.generate-profiles/data/profiles/{plate}/{plate}_augmented.csv.gz"

    annotate_df = pd.read_csv(link)

    norm_file = pathlib.Path(f"{output_dir}/{plate}_wholeplate_normalized.csv.gz")
    # feat_select_file = pathlib.Path(f"{output_dir}/{plate}_wholeplate_normalized_feature_selected.csv.gz")

    normalize(
        profiles=annotate_df,
        features="infer",
        meta_features=meta_features,
        samples="all",
        method="mad_robustize",
        output_file=norm_file,
        compression_options={"method": "gzip", "mtime": 1},
    )

# %%
# Define the plates
plates = [
    "SQ00014610",
    "SQ00014611",
    "SQ00014612",
    "SQ00014613",
    "SQ00014614",
    "SQ00014615",
    "SQ00014616",
    "SQ00014617",
    "SQ00014618",
]

# Define metadata features
meta_features = [
    "Image_Metadata_Plate",
    "Image_Metadata_Well",
    "Metadata_WellRow",
    "Metadata_WellCol",
    "Metadata_gene_name",
    "Metadata_pert_name",
    "Metadata_broad_sample",
    "Metadata_cell_line",
]

output_dir = pathlib.Path("data/cell-health/profiles")

commit = "cd91bd0daacef2b5ea25dcceb62482bb664d9de1"

# %%
for plate in tqdm(plates):
    normalize_profile(plate, output_dir, commit)
# Out:
# 100%|██████████| 9/9 [01:30<00:00, 10.06s/it]

# %% [markdown]
# ## Now form a single merged dataset to perform feature selection

# %%
# Load different normalized data
plate_files = [x for x in output_dir.iterdir() if "_normalized.csv.gz" in x.name]

# %%
# Concatentate all plates
x_df = (
    pd.concat([pd.read_csv(x) for x in plate_files], sort=True)
    .rename(
        {
            "Image_Metadata_Plate": "Metadata_Plate",
            "Image_Metadata_Well": "Metadata_Well",
        },
        axis="columns",
    )
    .drop(["Metadata_broad_sample"], axis="columns")
)

# Realign metadata column names
x_metadata_cols = x_df.columns[x_df.columns.str.startswith("Metadata")]
x_metadata_df = x_df.loc[:, x_metadata_cols]

x_df = x_df.drop(x_metadata_cols, axis="columns")
x_df = pd.concat([x_metadata_df, x_df], axis="columns")

print(x_df.shape)
x_df.head()
# Out:
# (3456, 1790)
#   Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0     SQ00014612           A01                 1                A
# 1     SQ00014612           A02                 2                A
# 2     SQ00014612           A03                 3                A
# 3     SQ00014612           A04                 4                A
# 4     SQ00014612           A05                 5                A
#
#   Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0               A549              EMPTY              EMPTY
# 1               A549               MCL1             MCL1-5
# 2               A549               AKT1             AKT1-1
# 3               A549               KRAS            KRAS-2B
# 4               A549               AKT1             AKT1-2
#
#    Cells_AreaShape_Area  Cells_AreaShape_Center_X  Cells_AreaShape_Center_Y  \
# 0             -1.791960                  0.035973                 -0.422573
# 1             -1.650852                  1.798642                  0.000000
# 2             -0.825819                  1.906561                  0.438825
# 3             -2.052952                 -0.071946                  0.520089
# 4             -1.523107                  0.971267                  0.032506
#
#    ...  Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0  ...                         0.762343                         2.211214
# 1  ...                         0.484508                         2.250169
# 2  ...                         0.911406                         2.449983
# 3  ...                         0.978916                         1.900017
# 4  ...                         0.222017                         2.055557
#
#    Nuclei_Texture_Variance_ER_20_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                         1.211959                        2.460510
# 1                         1.126989                        2.269059
# 2                         2.086322                        2.240322
# 3                         0.468119                        2.142986
# 4                         1.554514                        2.038328
#
#    Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_20_0  \
# 0                           1.318201                           0.904173
# 1                           1.464555                           1.149692
# 2                           1.551818                           1.824093
# 3                           1.111607                           0.520477
# 4                           1.041199                           1.547912
#
#    Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                          1.180967                          0.283193
# 1                          1.259498                          0.538925
# 2                          1.246285                          0.076692
# 3                          1.000640                         -0.689098
# 4                          0.584615                          0.029147
#
#    Nuclei_Texture_Variance_RNA_20_0  Nuclei_Texture_Variance_RNA_5_0
# 0                         -0.604721                         0.891250
# 1                         -0.352901                         0.961563
# 2                         -0.369901                         0.570666
# 3                         -1.738253                        -0.276086
# 4                         -0.707015                         0.414359
#
# [5 rows x 1790 columns]

# %%
# Perform feature selection
feature_select_ops = [
    "variance_threshold",
    "correlation_threshold",
    "drop_na_columns",
    "blocklist",
    "drop_outliers",
]

x_df = feature_select(profiles=x_df, operation=feature_select_ops, na_cutoff=0)

print(x_df.shape)
x_df
# Out:
# (3456, 517)
#     Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0       SQ00014612           A01                 1                A
# 1       SQ00014612           A02                 2                A
# 2       SQ00014612           A03                 3                A
# 3       SQ00014612           A04                 4                A
# 4       SQ00014612           A05                 5                A
# ..             ...           ...               ...              ...
# 379     SQ00014613           P20                20                P
# 380     SQ00014613           P21                21                P
# 381     SQ00014613           P22                22                P
# 382     SQ00014613           P23                23                P
# 383     SQ00014613           P24                24                P
#
#     Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0                 A549              EMPTY              EMPTY
# 1                 A549               MCL1             MCL1-5
# 2                 A549               AKT1             AKT1-1
# 3                 A549               KRAS            KRAS-2B
# 4                 A549               AKT1             AKT1-2
# ..                 ...                ...                ...
# 379                ES2               Chr2             Chr2-4
# 380                ES2              EMPTY              EMPTY
# 381                ES2             POLR2D           POLR2D-2
# 382                ES2               PPIB             PPIB-2
# 383                ES2               Chr2             Chr2-1
#
#      Cells_AreaShape_Compactness  Cells_AreaShape_Extent  \
# 0                      -0.378191               -0.030782
# 1                       0.739037               -0.466950
# 2                       0.663179               -0.614422
# 3                       1.142720               -1.444163
# 4                       0.506535               -0.384485
# ..                           ...                     ...
# 379                    -0.682856                1.065890
# 380                    -0.167718                0.326432
# 381                     0.825134               -1.343931
# 382                    -0.026582                0.409760
# 383                     0.397799                0.202151
#
#      Cells_AreaShape_FormFactor  ...  Nuclei_Texture_SumAverage_DNA_20_0  \
# 0                      2.089629  ...                           -2.462620
# 1                      2.245620  ...                           -2.527320
# 2                      1.552016  ...                           -0.861919
# 3                      2.473148  ...                           -1.710899
# 4                      2.334123  ...                           -1.934975
# ..                          ...  ...                                 ...
# 379                    0.249829  ...                            1.426622
# 380                   -0.671362  ...                            0.575870
# 381                   -1.244786  ...                            0.586443
# 382                   -1.885286  ...                            0.520229
# 383                   -0.985852  ...                           -0.011724
#
#      Nuclei_Texture_SumAverage_ER_20_0  Nuclei_Texture_SumAverage_Mito_5_0  \
# 0                             2.556333                            0.635753
# 1                             2.099596                            0.387399
# 2                             1.447807                            0.372708
# 3                             2.102723                            1.144608
# 4                             1.380920                           -0.091729
# ..                                 ...                                 ...
# 379                          -1.377794                           -1.181549
# 380                          -2.570827                           -1.134039
# 381                           0.112912                           -1.565975
# 382                          -2.690358                           -1.749121
# 383                          -2.236467                           -1.531853
#
#      Nuclei_Texture_SumAverage_RNA_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                             2.262901                            1.020190
# 1                             1.606377                            0.619004
# 2                             1.232601                            0.744217
# 3                             2.397073                            1.158156
# 4                             1.584126                            0.110702
# ..                                 ...                                 ...
# 379                          -0.949335                           -1.054564
# 380                          -0.703302                           -1.251033
# 381                          -0.367032                           -1.076886
# 382                          -1.007546                           -1.702999
# 383                          -1.023037                           -1.198184
#
#      Nuclei_Texture_SumEntropy_RNA_20_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                             -1.051497                           1.690149
# 1                             -1.123289                           1.319333
# 2                              0.065222                           1.338340
# 3                             -1.639257                           1.082772
# 4                             -0.332856                           0.630777
# ..                                  ...                                ...
# 379                            0.215409                           0.147263
# 380                            1.073462                           0.888439
# 381                           -0.862479                          -0.640960
# 382                            1.137241                           1.008825
# 383                            1.820137                           0.943971
#
#      Nuclei_Texture_Variance_ER_20_0  Nuclei_Texture_Variance_Mito_20_0  \
# 0                           1.211959                           0.904173
# 1                           1.126989                           1.149692
# 2                           2.086322                           1.824093
# 3                           0.468119                           0.520477
# 4                           1.554514                           1.547912
# ..                               ...                                ...
# 379                         0.291476                          -0.281496
# 380                        -1.108953                          -1.346037
# 381                        -0.096550                           0.307688
# 382                        -0.914257                          -1.062819
# 383                        -0.679193                          -0.934862
#
#      Nuclei_Texture_Variance_RNA_10_0
# 0                            0.283193
# 1                            0.538925
# 2                            0.076692
# 3                           -0.689098
# 4                            0.029147
# ..                                ...
# 379                          1.065962
# 380                          1.883433
# 381                         -0.079216
# 382                          2.591231
# 383                          2.485455
#
# [3456 rows x 517 columns]

# %%
# Also drop Costes features
costes_cols_to_drop = [x for x in x_df.columns if "costes" in x.lower()]
print("Dropping {} costes features".format(len(costes_cols_to_drop)))
x_df = x_df.drop(costes_cols_to_drop, axis="columns")

print(x_df.shape)
x_df
# Out:
# Dropping 4 costes features
# (3456, 513)
#     Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0       SQ00014612           A01                 1                A
# 1       SQ00014612           A02                 2                A
# 2       SQ00014612           A03                 3                A
# 3       SQ00014612           A04                 4                A
# 4       SQ00014612           A05                 5                A
# ..             ...           ...               ...              ...
# 379     SQ00014613           P20                20                P
# 380     SQ00014613           P21                21                P
# 381     SQ00014613           P22                22                P
# 382     SQ00014613           P23                23                P
# 383     SQ00014613           P24                24                P
#
#     Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0                 A549              EMPTY              EMPTY
# 1                 A549               MCL1             MCL1-5
# 2                 A549               AKT1             AKT1-1
# 3                 A549               KRAS            KRAS-2B
# 4                 A549               AKT1             AKT1-2
# ..                 ...                ...                ...
# 379                ES2               Chr2             Chr2-4
# 380                ES2              EMPTY              EMPTY
# 381                ES2             POLR2D           POLR2D-2
# 382                ES2               PPIB             PPIB-2
# 383                ES2               Chr2             Chr2-1
#
#      Cells_AreaShape_Compactness  Cells_AreaShape_Extent  \
# 0                      -0.378191               -0.030782
# 1                       0.739037               -0.466950
# 2                       0.663179               -0.614422
# 3                       1.142720               -1.444163
# 4                       0.506535               -0.384485
# ..                           ...                     ...
# 379                    -0.682856                1.065890
# 380                    -0.167718                0.326432
# 381                     0.825134               -1.343931
# 382                    -0.026582                0.409760
# 383                     0.397799                0.202151
#
#      Cells_AreaShape_FormFactor  ...  Nuclei_Texture_SumAverage_DNA_20_0  \
# 0                      2.089629  ...                           -2.462620
# 1                      2.245620  ...                           -2.527320
# 2                      1.552016  ...                           -0.861919
# 3                      2.473148  ...                           -1.710899
# 4                      2.334123  ...                           -1.934975
# ..                          ...  ...                                 ...
# 379                    0.249829  ...                            1.426622
# 380                   -0.671362  ...                            0.575870
# 381                   -1.244786  ...                            0.586443
# 382                   -1.885286  ...                            0.520229
# 383                   -0.985852  ...                           -0.011724
#
#      Nuclei_Texture_SumAverage_ER_20_0  Nuclei_Texture_SumAverage_Mito_5_0  \
# 0                             2.556333                            0.635753
# 1                             2.099596                            0.387399
# 2                             1.447807                            0.372708
# 3                             2.102723                            1.144608
# 4                             1.380920                           -0.091729
# ..                                 ...                                 ...
# 379                          -1.377794                           -1.181549
# 380                          -2.570827                           -1.134039
# 381                           0.112912                           -1.565975
# 382                          -2.690358                           -1.749121
# 383                          -2.236467                           -1.531853
#
#      Nuclei_Texture_SumAverage_RNA_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                             2.262901                            1.020190
# 1                             1.606377                            0.619004
# 2                             1.232601                            0.744217
# 3                             2.397073                            1.158156
# 4                             1.584126                            0.110702
# ..                                 ...                                 ...
# 379                          -0.949335                           -1.054564
# 380                          -0.703302                           -1.251033
# 381                          -0.367032                           -1.076886
# 382                          -1.007546                           -1.702999
# 383                          -1.023037                           -1.198184
#
#      Nuclei_Texture_SumEntropy_RNA_20_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                             -1.051497                           1.690149
# 1                             -1.123289                           1.319333
# 2                              0.065222                           1.338340
# 3                             -1.639257                           1.082772
# 4                             -0.332856                           0.630777
# ..                                  ...                                ...
# 379                            0.215409                           0.147263
# 380                            1.073462                           0.888439
# 381                           -0.862479                          -0.640960
# 382                            1.137241                           1.008825
# 383                            1.820137                           0.943971
#
#      Nuclei_Texture_Variance_ER_20_0  Nuclei_Texture_Variance_Mito_20_0  \
# 0                           1.211959                           0.904173
# 1                           1.126989                           1.149692
# 2                           2.086322                           1.824093
# 3                           0.468119                           0.520477
# 4                           1.554514                           1.547912
# ..                               ...                                ...
# 379                         0.291476                          -0.281496
# 380                        -1.108953                          -1.346037
# 381                        -0.096550                           0.307688
# 382                        -0.914257                          -1.062819
# 383                        -0.679193                          -0.934862
#
#      Nuclei_Texture_Variance_RNA_10_0
# 0                            0.283193
# 1                            0.538925
# 2                            0.076692
# 3                           -0.689098
# 4                            0.029147
# ..                                ...
# 379                          1.065962
# 380                          1.883433
# 381                         -0.079216
# 382                          2.591231
# 383                          2.485455
#
# [3456 rows x 513 columns]

# %%
# Output
profile_file = pathlib.Path(f"{output_dir}/cell_health_profiles_merged_wholeplate_normalized_featureselected.tsv.gz")
x_df.to_csv(profile_file, index=False, sep="\t")

# %% [markdown]
# ## Add sphering

# %%
# x_df = normalize(
#     profiles=x_df,
#     features="infer",
#     meta_features=x_df.filter(regex="Metadata_").columns.tolist(),
#     samples="Metadata_gene_name == 'EMPTY'",
#     method="spherize",
# )

x_df
# Out:
#     Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0       SQ00014612           A01                 1                A
# 1       SQ00014612           A02                 2                A
# 2       SQ00014612           A03                 3                A
# 3       SQ00014612           A04                 4                A
# 4       SQ00014612           A05                 5                A
# ..             ...           ...               ...              ...
# 379     SQ00014613           P20                20                P
# 380     SQ00014613           P21                21                P
# 381     SQ00014613           P22                22                P
# 382     SQ00014613           P23                23                P
# 383     SQ00014613           P24                24                P
#
#     Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0                 A549              EMPTY              EMPTY
# 1                 A549               MCL1             MCL1-5
# 2                 A549               AKT1             AKT1-1
# 3                 A549               KRAS            KRAS-2B
# 4                 A549               AKT1             AKT1-2
# ..                 ...                ...                ...
# 379                ES2               Chr2             Chr2-4
# 380                ES2              EMPTY              EMPTY
# 381                ES2             POLR2D           POLR2D-2
# 382                ES2               PPIB             PPIB-2
# 383                ES2               Chr2             Chr2-1
#
#      Cells_AreaShape_Compactness  Cells_AreaShape_Extent  \
# 0                      -0.378191               -0.030782
# 1                       0.739037               -0.466950
# 2                       0.663179               -0.614422
# 3                       1.142720               -1.444163
# 4                       0.506535               -0.384485
# ..                           ...                     ...
# 379                    -0.682856                1.065890
# 380                    -0.167718                0.326432
# 381                     0.825134               -1.343931
# 382                    -0.026582                0.409760
# 383                     0.397799                0.202151
#
#      Cells_AreaShape_FormFactor  ...  Nuclei_Texture_SumAverage_DNA_20_0  \
# 0                      2.089629  ...                           -2.462620
# 1                      2.245620  ...                           -2.527320
# 2                      1.552016  ...                           -0.861919
# 3                      2.473148  ...                           -1.710899
# 4                      2.334123  ...                           -1.934975
# ..                          ...  ...                                 ...
# 379                    0.249829  ...                            1.426622
# 380                   -0.671362  ...                            0.575870
# 381                   -1.244786  ...                            0.586443
# 382                   -1.885286  ...                            0.520229
# 383                   -0.985852  ...                           -0.011724
#
#      Nuclei_Texture_SumAverage_ER_20_0  Nuclei_Texture_SumAverage_Mito_5_0  \
# 0                             2.556333                            0.635753
# 1                             2.099596                            0.387399
# 2                             1.447807                            0.372708
# 3                             2.102723                            1.144608
# 4                             1.380920                           -0.091729
# ..                                 ...                                 ...
# 379                          -1.377794                           -1.181549
# 380                          -2.570827                           -1.134039
# 381                           0.112912                           -1.565975
# 382                          -2.690358                           -1.749121
# 383                          -2.236467                           -1.531853
#
#      Nuclei_Texture_SumAverage_RNA_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                             2.262901                            1.020190
# 1                             1.606377                            0.619004
# 2                             1.232601                            0.744217
# 3                             2.397073                            1.158156
# 4                             1.584126                            0.110702
# ..                                 ...                                 ...
# 379                          -0.949335                           -1.054564
# 380                          -0.703302                           -1.251033
# 381                          -0.367032                           -1.076886
# 382                          -1.007546                           -1.702999
# 383                          -1.023037                           -1.198184
#
#      Nuclei_Texture_SumEntropy_RNA_20_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                             -1.051497                           1.690149
# 1                             -1.123289                           1.319333
# 2                              0.065222                           1.338340
# 3                             -1.639257                           1.082772
# 4                             -0.332856                           0.630777
# ..                                  ...                                ...
# 379                            0.215409                           0.147263
# 380                            1.073462                           0.888439
# 381                           -0.862479                          -0.640960
# 382                            1.137241                           1.008825
# 383                            1.820137                           0.943971
#
#      Nuclei_Texture_Variance_ER_20_0  Nuclei_Texture_Variance_Mito_20_0  \
# 0                           1.211959                           0.904173
# 1                           1.126989                           1.149692
# 2                           2.086322                           1.824093
# 3                           0.468119                           0.520477
# 4                           1.554514                           1.547912
# ..                               ...                                ...
# 379                         0.291476                          -0.281496
# 380                        -1.108953                          -1.346037
# 381                        -0.096550                           0.307688
# 382                        -0.914257                          -1.062819
# 383                        -0.679193                          -0.934862
#
#      Nuclei_Texture_Variance_RNA_10_0
# 0                            0.283193
# 1                            0.538925
# 2                            0.076692
# 3                           -0.689098
# 4                            0.029147
# ..                                ...
# 379                          1.065962
# 380                          1.883433
# 381                         -0.079216
# 382                          2.591231
# 383                          2.485455
#
# [3456 rows x 513 columns]

# %%
# profile_file = pathlib.Path(f"{output_dir}/cell_health_profiles_merged_wholeplate_normalized_featureselected_spherized.tsv.gz")
# x_df.to_csv(profile_file, index=False, sep="\t")

# %%
x_df = sphere(x_df, regularization=1e-5, mode="corr", column_norm="Metadata_gene_name", values_norm=["EMPTY"])[0]
x_df
# Out:
#     Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0       SQ00014612           A01                 1                A
# 1       SQ00014612           A02                 2                A
# 2       SQ00014612           A03                 3                A
# 3       SQ00014612           A04                 4                A
# 4       SQ00014612           A05                 5                A
# ..             ...           ...               ...              ...
# 379     SQ00014613           P20                20                P
# 380     SQ00014613           P21                21                P
# 381     SQ00014613           P22                22                P
# 382     SQ00014613           P23                23                P
# 383     SQ00014613           P24                24                P
#
#     Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0                 A549              EMPTY              EMPTY
# 1                 A549               MCL1             MCL1-5
# 2                 A549               AKT1             AKT1-1
# 3                 A549               KRAS            KRAS-2B
# 4                 A549               AKT1             AKT1-2
# ..                 ...                ...                ...
# 379                ES2               Chr2             Chr2-4
# 380                ES2              EMPTY              EMPTY
# 381                ES2             POLR2D           POLR2D-2
# 382                ES2               PPIB             PPIB-2
# 383                ES2               Chr2             Chr2-1
#
#      Cells_AreaShape_Compactness  Cells_AreaShape_Extent  \
# 0                      -1.935996               -0.673692
# 1                      -5.766285                9.060817
# 2                      -1.598747               -5.361239
# 3                       2.168759              -10.507735
# 4                       2.246771               -7.710614
# ..                           ...                     ...
# 379                    -3.154688               -1.109687
# 380                     0.229929               -0.652326
# 381                     4.475561                3.567198
# 382                   -11.605747               10.024449
# 383                    -0.846795               -2.004164
#
#      Cells_AreaShape_FormFactor  ...  Nuclei_Texture_SumAverage_DNA_20_0  \
# 0                      0.847742  ...                           -1.532641
# 1                     -4.167489  ...                           -4.497974
# 2                      8.036478  ...                           -1.667609
# 3                     -6.338868  ...                            3.232671
# 4                      1.823458  ...                           -2.131146
# ..                          ...  ...                                 ...
# 379                    7.828422  ...                           -1.921272
# 380                   -0.467426  ...                            0.208389
# 381                    3.232490  ...                          -12.754598
# 382                  -14.671390  ...                            0.451709
# 383                   12.479921  ...                           24.978549
#
#      Nuclei_Texture_SumAverage_ER_20_0  Nuclei_Texture_SumAverage_Mito_5_0  \
# 0                             0.113030                            0.433600
# 1                           -10.435532                            0.824320
# 2                             0.590655                          -12.083847
# 3                            -4.023018                           -4.859928
# 4                            -0.191313                          -10.390250
# ..                                 ...                                 ...
# 379                          12.260365                           -6.088907
# 380                           0.885847                            0.948840
# 381                         -13.915999                           25.838897
# 382                         -10.725376                          -19.136646
# 383                         -20.640541                          -20.648448
#
#      Nuclei_Texture_SumAverage_RNA_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                             0.255874                           -0.518409
# 1                             1.875632                            4.994489
# 2                             4.326957                            3.125793
# 3                             5.658337                            3.489841
# 4                             1.773041                           -8.999976
# ..                                 ...                                 ...
# 379                          -5.932748                           -0.801599
# 380                           0.444595                            0.287073
# 381                           6.346540                           18.824343
# 382                          10.603513                            5.215194
# 383                          -8.458189                            9.240273
#
#      Nuclei_Texture_SumEntropy_RNA_20_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                             -1.146619                           1.118104
# 1                              0.319888                           0.934372
# 2                             -0.597046                          -6.557250
# 3                              1.664227                          -1.002914
# 4                             -0.078887                          -6.427427
# ..                                  ...                                ...
# 379                            3.603677                           7.224991
# 380                            0.548459                           0.873887
# 381                            7.043592                         -10.681416
# 382                           -5.147056                           0.264905
# 383                           -2.106431                          -5.122875
#
#      Nuclei_Texture_Variance_ER_20_0  Nuclei_Texture_Variance_Mito_20_0  \
# 0                           1.150425                           0.567928
# 1                          -0.002759                          -1.218939
# 2                           1.775098                          -0.041881
# 3                           3.163857                          -5.282648
# 4                           1.354188                           5.611050
# ..                               ...                                ...
# 379                         0.144833                          -1.720884
# 380                        -0.053018                          -0.427338
# 381                       -13.615297                          -3.306112
# 382                        -2.345584                           1.625935
# 383                       -10.989158                          12.422251
#
#      Nuclei_Texture_Variance_RNA_10_0
# 0                            0.369171
# 1                            2.291609
# 2                            3.093983
# 3                           -0.744153
# 4                           -2.634557
# ..                                ...
# 379                          8.955756
# 380                          1.206029
# 381                          4.882997
# 382                          7.503229
# 383                         -7.972899
#
# [3456 rows x 513 columns]

# %%
profile_file = pathlib.Path(f"{output_dir}/cell_health_profiles_merged_wholeplate_normalized_featureselected_spherized.tsv.gz")
x_df.to_csv(profile_file, index=False, sep="\t")

# %% [markdown]
# ## Save not normalized profiles

# %%
def load_raw_profiles(plate, commit="cd91bd0daacef2b5ea25dcceb62482bb664d9de1"):
    link = f"https://github.com/broadinstitute/cell-health/raw/{commit}/1.generate-profiles/data/profiles/{plate}/{plate}_augmented.csv.gz"

    return pd.read_csv(link)

# %%
raw_profiles = pd.concat([load_raw_profiles(plate, commit) for plate in tqdm(plates)], sort=True)
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.23it/s]

# %%
x_df = (
    raw_profiles
    .rename(
        {
            "Image_Metadata_Plate": "Metadata_Plate",
            "Image_Metadata_Well": "Metadata_Well",
        },
        axis="columns",
    )
    .drop(["Metadata_broad_sample"], axis="columns")
)

# Realign metadata column names
x_metadata_cols = x_df.columns[x_df.columns.str.startswith("Metadata")]
x_metadata_df = x_df.loc[:, x_metadata_cols]

x_df = x_df.drop(x_metadata_cols, axis="columns")
x_df = pd.concat([x_metadata_df, x_df], axis="columns").reset_index(drop=True)

print(x_df.shape)
x_df
# Out:
# (3456, 1790)
#      Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0        SQ00014610           A01                 1                A
# 1        SQ00014610           A02                 2                A
# 2        SQ00014610           A03                 3                A
# 3        SQ00014610           A04                 4                A
# 4        SQ00014610           A05                 5                A
# ...             ...           ...               ...              ...
# 3451     SQ00014618           P20                20                P
# 3452     SQ00014618           P21                21                P
# 3453     SQ00014618           P22                22                P
# 3454     SQ00014618           P23                23                P
# 3455     SQ00014618           P24                24                P
#
#      Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0                  A549              EMPTY              EMPTY
# 1                  A549               MCL1             MCL1-5
# 2                  A549               AKT1             AKT1-1
# 3                  A549               KRAS            KRAS-2B
# 4                  A549               AKT1             AKT1-2
# ...                 ...                ...                ...
# 3451              HCC44               Chr2             Chr2-4
# 3452              HCC44              EMPTY              EMPTY
# 3453              HCC44             POLR2D           POLR2D-2
# 3454              HCC44               PPIB             PPIB-2
# 3455              HCC44               Chr2             Chr2-1
#
#       Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# 0                   6142.0                    1087.0
# 1                   7981.5                    1074.0
# 2                   7772.5                    1057.0
# 3                   7899.0                    1042.5
# 4                   6127.0                    1081.0
# ...                    ...                       ...
# 3451               11255.5                    1096.0
# 3452               11076.0                    1086.0
# 3453               19025.0                    1079.0
# 3454               12710.0                    1110.0
# 3455               13151.0                    1101.5
#
#       Cells_AreaShape_Center_Y  ...  Nuclei_Texture_Variance_DNA_5_0  \
# 0                       1108.0  ...                         3.559823
# 1                       1084.0  ...                         3.461207
# 2                       1122.5  ...                         3.330129
# 3                       1069.5  ...                         3.161432
# 4                       1089.0  ...                         3.451520
# ...                        ...  ...                              ...
# 3451                    1078.5  ...                         3.041736
# 3452                    1031.5  ...                         2.737910
# 3453                    1002.0  ...                         3.162322
# 3454                    1048.5  ...                         2.930082
# 3455                    1123.5  ...                         2.577867
#
#       Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                            2.321827                         2.215901
# 1                            2.144722                         1.968777
# 2                            2.111943                         1.962466
# 3                            2.047220                         1.911537
# 4                            2.047491                         1.723013
# ...                               ...                              ...
# 3451                         2.189158                         2.099769
# 3452                         2.170629                         2.048944
# 3453                         2.058264                         1.872603
# 3454                         2.204242                         2.073079
# 3455                         1.971451                         1.848535
#
#       Nuclei_Texture_Variance_ER_5_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                           2.348993                           2.067028
# 1                           2.201527                           1.892255
# 2                           2.141256                           1.832483
# 3                           2.111766                           1.826544
# 4                           2.139267                           1.947429
# ...                              ...                                ...
# 3451                        2.291720                           1.865265
# 3452                        2.258886                           1.796615
# 3453                        2.187862                           1.857193
# 3454                        2.289184                           1.792738
# 3455                        2.056487                           1.749860
#
#       Nuclei_Texture_Variance_Mito_20_0  Nuclei_Texture_Variance_Mito_5_0  \
# 0                              1.875259                          2.230317
# 1                              1.716484                          2.094723
# 2                              1.668058                          1.987148
# 3                              1.669786                          1.952193
# 4                              1.699718                          2.130986
# ...                                 ...                               ...
# 3451                           1.705550                          1.989196
# 3452                           1.638885                          1.926364
# 3453                           1.621113                          2.032905
# 3454                           1.628610                          1.928525
# 3455                           1.579143                          1.893054
#
#       Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_20_0  \
# 0                             2.911926                          2.641810
# 1                             3.000435                          2.806122
# 2                             2.935527                          2.720891
# 3                             2.918356                          2.824358
# 4                             2.898105                          2.656090
# ...                                ...                               ...
# 3451                          2.403242                          2.294250
# 3452                          2.462477                          2.342575
# 3453                          2.368877                          2.311463
# 3454                          2.452355                          2.372163
# 3455                          2.501960                          2.440450
#
#       Nuclei_Texture_Variance_RNA_5_0
# 0                            2.997173
# 1                            3.056962
# 2                            2.985796
# 3                            2.854221
# 4                            2.934385
# ...                               ...
# 3451                         2.465146
# 3452                         2.511645
# 3453                         2.423977
# 3454                         2.490241
# 3455                         2.536668
#
# [3456 rows x 1790 columns]

# %%
x_df = normalize(
    profiles=x_df,
    features="infer",
    meta_features=x_df.filter(regex="Metadata_").columns.tolist(),
    samples="all",
    method="standardize"
)
x_df
# Out:
#      Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0        SQ00014610           A01                 1                A
# 1        SQ00014610           A02                 2                A
# 2        SQ00014610           A03                 3                A
# 3        SQ00014610           A04                 4                A
# 4        SQ00014610           A05                 5                A
# ...             ...           ...               ...              ...
# 3451     SQ00014618           P20                20                P
# 3452     SQ00014618           P21                21                P
# 3453     SQ00014618           P22                22                P
# 3454     SQ00014618           P23                23                P
# 3455     SQ00014618           P24                24                P
#
#      Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0                  A549              EMPTY              EMPTY
# 1                  A549               MCL1             MCL1-5
# 2                  A549               AKT1             AKT1-1
# 3                  A549               KRAS            KRAS-2B
# 4                  A549               AKT1             AKT1-2
# ...                 ...                ...                ...
# 3451              HCC44               Chr2             Chr2-4
# 3452              HCC44              EMPTY              EMPTY
# 3453              HCC44             POLR2D           POLR2D-2
# 3454              HCC44               PPIB             PPIB-2
# 3455              HCC44               Chr2             Chr2-1
#
#       Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# 0                -1.440620                 -0.297351
# 1                -0.820022                 -0.593748
# 2                -0.890533                 -0.981345
# 3                -0.847855                 -1.311942
# 4                -1.445681                 -0.434150
# ...                    ...                       ...
# 3451              0.284539                 -0.092153
# 3452              0.223981                 -0.320151
# 3453              2.905763                 -0.479749
# 3454              0.775249                  0.227045
# 3455              0.924031                  0.033246
#
#       Cells_AreaShape_Center_Y  ...  Nuclei_Texture_Variance_DNA_5_0  \
# 0                     0.713185  ...                         0.427678
# 1                     0.157797  ...                         0.169831
# 2                     1.048732  ...                        -0.172889
# 3                    -0.177750  ...                        -0.613971
# 4                     0.273502  ...                         0.144505
# ...                        ...  ...                              ...
# 3451                  0.030520  ...                        -0.926931
# 3452                 -1.057115  ...                        -1.721325
# 3453                 -1.739780  ...                        -0.611642
# 3454                 -0.663715  ...                        -1.218865
# 3455                  1.071873  ...                        -2.139777
#
#       Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                            1.282520                         1.493875
# 1                            0.076940                         0.024301
# 2                           -0.146191                        -0.013228
# 3                           -0.586773                        -0.316083
# 4                           -0.584928                        -1.437178
# ...                               ...                              ...
# 3451                         0.379419                         0.803273
# 3452                         0.253292                         0.501032
# 3453                        -0.511595                        -0.547615
# 3454                         0.482099                         0.644556
# 3455                        -1.102543                        -0.690734
#
#       Nuclei_Texture_Variance_ER_5_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                           0.844112                           1.346465
# 1                          -0.156710                           0.383498
# 2                          -0.565758                           0.054167
# 3                          -0.765898                           0.021440
# 4                          -0.579254                           0.687498
# ...                              ...                                ...
# 3451                        0.455408                           0.234789
# 3452                        0.232570                          -0.143463
# 3453                       -0.249453                           0.190314
# 3454                        0.438197                          -0.164824
# 3455                       -1.141067                          -0.401076
#
#       Nuclei_Texture_Variance_Mito_20_0  Nuclei_Texture_Variance_Mito_5_0  \
# 0                              1.535849                          1.287128
# 1                              0.507997                          0.591366
# 2                              0.194504                          0.039379
# 3                              0.205691                         -0.139984
# 4                              0.399458                          0.777442
# ...                                 ...                               ...
# 3451                           0.437217                          0.049888
# 3452                           0.005651                         -0.272520
# 3453                          -0.109398                          0.274164
# 3454                          -0.060865                         -0.261433
# 3455                          -0.381098                         -0.443442
#
#       Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_20_0  \
# 0                             1.289999                          1.043189
# 1                             1.548969                          1.647975
# 2                             1.359054                          1.334264
# 3                             1.308812                          1.715099
# 4                             1.249560                          1.095750
# ...                                ...                               ...
# 3451                         -0.198370                         -0.236087
# 3452                         -0.025052                         -0.058216
# 3453                         -0.298920                         -0.172729
# 3454                         -0.054668                          0.050691
# 3455                          0.090471                          0.302038
#
#       Nuclei_Texture_Variance_RNA_5_0
# 0                            1.364738
# 1                            1.528259
# 2                            1.333620
# 3                            0.973765
# 4                            1.193013
# ...                               ...
# 3451                        -0.090345
# 3452                         0.036826
# 3453                        -0.202944
# 3454                        -0.021712
# 3455                         0.105264
#
# [3456 rows x 1790 columns]

# %%
# Perform feature selection
feature_select_ops = [
    "variance_threshold",
    "correlation_threshold",
    "drop_na_columns",
    "blocklist",
    "drop_outliers",
]

x_df = feature_select(profiles=x_df, operation=feature_select_ops, na_cutoff=0)

print(x_df.shape)
x_df
# Out:
# (3456, 405)
#      Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0        SQ00014610           A01                 1                A
# 1        SQ00014610           A02                 2                A
# 2        SQ00014610           A03                 3                A
# 3        SQ00014610           A04                 4                A
# 4        SQ00014610           A05                 5                A
# ...             ...           ...               ...              ...
# 3451     SQ00014618           P20                20                P
# 3452     SQ00014618           P21                21                P
# 3453     SQ00014618           P22                22                P
# 3454     SQ00014618           P23                23                P
# 3455     SQ00014618           P24                24                P
#
#      Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0                  A549              EMPTY              EMPTY
# 1                  A549               MCL1             MCL1-5
# 2                  A549               AKT1             AKT1-1
# 3                  A549               KRAS            KRAS-2B
# 4                  A549               AKT1             AKT1-2
# ...                 ...                ...                ...
# 3451              HCC44               Chr2             Chr2-4
# 3452              HCC44              EMPTY              EMPTY
# 3453              HCC44             POLR2D           POLR2D-2
# 3454              HCC44               PPIB             PPIB-2
# 3455              HCC44               Chr2             Chr2-1
#
#       Cells_AreaShape_FormFactor  Cells_AreaShape_Solidity  \
# 0                       1.389069                  0.544848
# 1                       0.589662                  0.834696
# 2                       0.468350                  0.723579
# 3                       2.074089                  0.907895
# 4                       0.990033                  0.655080
# ...                          ...                       ...
# 3451                    0.112918                  1.081731
# 3452                   -0.151096                  1.318775
# 3453                   -2.388129                  0.240751
# 3454                   -0.421905                  1.148067
# 3455                    0.268964                  1.119155
#
#       Cells_AreaShape_Zernike_1_1  ...  \
# 0                        1.115782  ...
# 1                        0.389911  ...
# 2                        0.855382  ...
# 3                        0.473071  ...
# 4                        0.401046  ...
# ...                           ...  ...
# 3451                     0.604378  ...
# 3452                     0.288216  ...
# 3453                     0.120395  ...
# 3454                     0.241985  ...
# 3455                    -0.019385  ...
#
#       Nuclei_Texture_InverseDifferenceMoment_Mito_10_0  \
# 0                                            -0.454312
# 1                                            -0.000350
# 2                                             0.176164
# 3                                             0.040333
# 4                                            -0.480897
# ...                                                ...
# 3451                                          0.709441
# 3452                                          0.852550
# 3453                                          1.999277
# 3454                                          1.021808
# 3455                                          1.014211
#
#       Nuclei_Texture_InverseDifferenceMoment_Mito_20_0  \
# 0                                            -1.092728
# 1                                            -0.647848
# 2                                            -0.487622
# 3                                            -0.662136
# 4                                            -1.114307
# ...                                                ...
# 3451                                          0.939859
# 3452                                          1.094910
# 3453                                          1.291891
# 3454                                          1.052520
# 3455                                          1.278177
#
#       Nuclei_Texture_InverseDifferenceMoment_Mito_5_0  \
# 0                                           -0.151705
# 1                                            0.556318
# 2                                            0.451854
# 3                                            0.297309
# 4                                           -0.149586
# ...                                               ...
# 3451                                         0.035536
# 3452                                        -0.190898
# 3453                                         2.273384
# 3454                                         0.405216
# 3455                                         0.246669
#
#       Nuclei_Texture_SumAverage_DNA_20_0  Nuclei_Texture_SumAverage_ER_20_0  \
# 0                              -0.292525                          -1.128694
# 1                              -0.104040                          -1.197435
# 2                               0.300909                          -1.303741
# 3                               0.404368                           0.346135
# 4                               0.066005                          -1.182267
# ...                                  ...                                ...
# 3451                           -0.259901                          -0.089036
# 3452                           -1.086341                          -0.367832
# 3453                           -0.905629                           0.354684
# 3454                           -0.766357                          -0.081998
# 3455                           -0.647799                          -0.059125
#
#       Nuclei_Texture_SumAverage_RNA_20_0  Nuclei_Texture_SumEntropy_DNA_10_0  \
# 0                              -0.300575                            0.517903
# 1                              -0.296174                            0.275071
# 2                              -0.717634                           -0.358357
# 3                              -0.698184                           -1.153863
# 4                              -0.443063                            0.199746
# ...                                  ...                                 ...
# 3451                            0.392783                           -0.296372
# 3452                            0.044236                           -1.551133
# 3453                            0.973695                            0.082808
# 3454                            0.254301                           -0.576479
# 3455                           -0.191853                           -2.362064
#
#       Nuclei_Texture_SumEntropy_Mito_20_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                               -0.491960                         1.282520
# 1                               -0.854271                         0.076940
# 2                               -1.369487                        -0.146191
# 3                               -1.156340                        -0.586773
# 4                               -0.616599                        -0.584928
# ...                                   ...                              ...
# 3451                             1.141510                         0.379419
# 3452                             0.896821                         0.253292
# 3453                             0.824652                        -0.511595
# 3454                             1.072265                         0.482099
# 3455                             0.929292                        -1.102543
#
#       Nuclei_Texture_Variance_Mito_20_0
# 0                              1.535849
# 1                              0.507997
# 2                              0.194504
# 3                              0.205691
# 4                              0.399458
# ...                                 ...
# 3451                           0.437217
# 3452                           0.005651
# 3453                          -0.109398
# 3454                          -0.060865
# 3455                          -0.381098
#
# [3456 rows x 405 columns]

# %%
# Also drop Costes features
costes_cols_to_drop = [x for x in x_df.columns if "costes" in x.lower()]
print("Dropping {} costes features".format(len(costes_cols_to_drop)))
x_df = x_df.drop(costes_cols_to_drop, axis="columns")

print(x_df.shape)
x_df
# Out:
# Dropping 2 costes features
# (3456, 403)
#      Metadata_Plate Metadata_Well  Metadata_WellCol Metadata_WellRow  \
# 0        SQ00014610           A01                 1                A
# 1        SQ00014610           A02                 2                A
# 2        SQ00014610           A03                 3                A
# 3        SQ00014610           A04                 4                A
# 4        SQ00014610           A05                 5                A
# ...             ...           ...               ...              ...
# 3451     SQ00014618           P20                20                P
# 3452     SQ00014618           P21                21                P
# 3453     SQ00014618           P22                22                P
# 3454     SQ00014618           P23                23                P
# 3455     SQ00014618           P24                24                P
#
#      Metadata_cell_line Metadata_gene_name Metadata_pert_name  \
# 0                  A549              EMPTY              EMPTY
# 1                  A549               MCL1             MCL1-5
# 2                  A549               AKT1             AKT1-1
# 3                  A549               KRAS            KRAS-2B
# 4                  A549               AKT1             AKT1-2
# ...                 ...                ...                ...
# 3451              HCC44               Chr2             Chr2-4
# 3452              HCC44              EMPTY              EMPTY
# 3453              HCC44             POLR2D           POLR2D-2
# 3454              HCC44               PPIB             PPIB-2
# 3455              HCC44               Chr2             Chr2-1
#
#       Cells_AreaShape_FormFactor  Cells_AreaShape_Solidity  \
# 0                       1.389069                  0.544848
# 1                       0.589662                  0.834696
# 2                       0.468350                  0.723579
# 3                       2.074089                  0.907895
# 4                       0.990033                  0.655080
# ...                          ...                       ...
# 3451                    0.112918                  1.081731
# 3452                   -0.151096                  1.318775
# 3453                   -2.388129                  0.240751
# 3454                   -0.421905                  1.148067
# 3455                    0.268964                  1.119155
#
#       Cells_AreaShape_Zernike_1_1  ...  \
# 0                        1.115782  ...
# 1                        0.389911  ...
# 2                        0.855382  ...
# 3                        0.473071  ...
# 4                        0.401046  ...
# ...                           ...  ...
# 3451                     0.604378  ...
# 3452                     0.288216  ...
# 3453                     0.120395  ...
# 3454                     0.241985  ...
# 3455                    -0.019385  ...
#
#       Nuclei_Texture_InverseDifferenceMoment_Mito_10_0  \
# 0                                            -0.454312
# 1                                            -0.000350
# 2                                             0.176164
# 3                                             0.040333
# 4                                            -0.480897
# ...                                                ...
# 3451                                          0.709441
# 3452                                          0.852550
# 3453                                          1.999277
# 3454                                          1.021808
# 3455                                          1.014211
#
#       Nuclei_Texture_InverseDifferenceMoment_Mito_20_0  \
# 0                                            -1.092728
# 1                                            -0.647848
# 2                                            -0.487622
# 3                                            -0.662136
# 4                                            -1.114307
# ...                                                ...
# 3451                                          0.939859
# 3452                                          1.094910
# 3453                                          1.291891
# 3454                                          1.052520
# 3455                                          1.278177
#
#       Nuclei_Texture_InverseDifferenceMoment_Mito_5_0  \
# 0                                           -0.151705
# 1                                            0.556318
# 2                                            0.451854
# 3                                            0.297309
# 4                                           -0.149586
# ...                                               ...
# 3451                                         0.035536
# 3452                                        -0.190898
# 3453                                         2.273384
# 3454                                         0.405216
# 3455                                         0.246669
#
#       Nuclei_Texture_SumAverage_DNA_20_0  Nuclei_Texture_SumAverage_ER_20_0  \
# 0                              -0.292525                          -1.128694
# 1                              -0.104040                          -1.197435
# 2                               0.300909                          -1.303741
# 3                               0.404368                           0.346135
# 4                               0.066005                          -1.182267
# ...                                  ...                                ...
# 3451                           -0.259901                          -0.089036
# 3452                           -1.086341                          -0.367832
# 3453                           -0.905629                           0.354684
# 3454                           -0.766357                          -0.081998
# 3455                           -0.647799                          -0.059125
#
#       Nuclei_Texture_SumAverage_RNA_20_0  Nuclei_Texture_SumEntropy_DNA_10_0  \
# 0                              -0.300575                            0.517903
# 1                              -0.296174                            0.275071
# 2                              -0.717634                           -0.358357
# 3                              -0.698184                           -1.153863
# 4                              -0.443063                            0.199746
# ...                                  ...                                 ...
# 3451                            0.392783                           -0.296372
# 3452                            0.044236                           -1.551133
# 3453                            0.973695                            0.082808
# 3454                            0.254301                           -0.576479
# 3455                           -0.191853                           -2.362064
#
#       Nuclei_Texture_SumEntropy_Mito_20_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                               -0.491960                         1.282520
# 1                               -0.854271                         0.076940
# 2                               -1.369487                        -0.146191
# 3                               -1.156340                        -0.586773
# 4                               -0.616599                        -0.584928
# ...                                   ...                              ...
# 3451                             1.141510                         0.379419
# 3452                             0.896821                         0.253292
# 3453                             0.824652                        -0.511595
# 3454                             1.072265                         0.482099
# 3455                             0.929292                        -1.102543
#
#       Nuclei_Texture_Variance_Mito_20_0
# 0                              1.535849
# 1                              0.507997
# 2                              0.194504
# 3                              0.205691
# 4                              0.399458
# ...                                 ...
# 3451                           0.437217
# 3452                           0.005651
# 3453                          -0.109398
# 3454                          -0.060865
# 3455                          -0.381098
#
# [3456 rows x 403 columns]

# %%
# Output
profile_file = pathlib.Path(f"{output_dir}/cell_health_profiles_merged_standardized_featureselected.tsv.gz")
x_df.to_csv(profile_file, index=False, sep="\t")
