# %% [markdown]
# ## Compare CERES readout

# %%
import pathlib

import numpy as np
import pandas as pd
import plotnine as gg

import mygene

import seaborn as sns
import matplotlib.pyplot as plt

# %%
output_dir = pathlib.Path("figures")
output_dir.mkdir(exist_ok=True)
cell_health_dir = pathlib.Path("../../1.calculate-metrics/cell-health/results")

# %%
# Load cell health grit scores
cell_health_grit_file = pathlib.Path(f"{cell_health_dir}/cell_health_map.tsv")

cell_health_grit_df = (
    pd.read_csv(cell_health_grit_file, sep="\t")
    # .query("cor_method == 'pearson'")
    # .query("grit_replicate_summary_method == 'mean'")
)

print(cell_health_grit_df.shape)
cell_health_grit_df.head()
# Out:
# (681, 8)
#   Metadata_gene_name Metadata_pert_name   mean_ap   p_value  n_pos_pairs  \
# 0               AKT1             AKT1-1  0.236639  0.123396         11.0
# 1               AKT1             AKT1-2  0.198102  0.148055         11.0
# 2             ARID1B           ARID1B-1  0.122817  0.166342         11.0
# 3             ARID1B           ARID1B-2  0.127141  0.141236         11.0
# 4               ATF4             ATF4-1  0.315895  0.023718         11.0
#
#    n_total_pairs cell_line  barcode_control
# 0          203.0     HCC44  cutting_control
# 1          203.0     HCC44  cutting_control
# 2          203.0     HCC44  cutting_control
# 3          203.0     HCC44  cutting_control
# 4          203.0     HCC44  cutting_control

# %%
mg = mygene.MyGeneInfo()

result = mg.querymany(
    cell_health_grit_df.Metadata_gene_name.unique().tolist(),
    scopes="symbol",
    species="human",
    fields="entrezgene,symbol,ensembl.gene,",
    as_dataframe=True,
)

ncbi_id_df = result.drop_duplicates(subset="_id").loc[:, ["_id"]].reset_index(drop=False)
ncbi_id_df.head(2)
# Out:
# 7 input query terms found no hit:	['ATP50', 'BRAF1', 'EMPTY', 'XBP', 'Chr2', 'LacZ', 'Luc']
#     query    _id
# 0    AKT1    207
# 1  ARID1B  57492

# %%
cell_health_grit_df = cell_health_grit_df.merge(ncbi_id_df, left_on="Metadata_gene_name", right_on="query", how="left")

print(cell_health_grit_df.shape)
cell_health_grit_df.head(2)
# Out:
# (681, 10)
#   Metadata_gene_name Metadata_pert_name   mean_ap   p_value  n_pos_pairs  \
# 0               AKT1             AKT1-1  0.236639  0.123396         11.0
# 1               AKT1             AKT1-2  0.198102  0.148055         11.0
#
#    n_total_pairs cell_line  barcode_control query  _id
# 0          203.0     HCC44  cutting_control  AKT1  207
# 1          203.0     HCC44  cutting_control  AKT1  207

# %%
# Load ceres data
ceres_dir = pathlib.Path("../../0.download-data/data/")
ceres_file = pathlib.Path(f"{ceres_dir}/ceres.csv")
depmap_sample_file = pathlib.Path(f"{ceres_dir}/depmap_sample_info.csv")

ceres_df = pd.read_csv(ceres_file, index_col=0)
depmap_sample_df = pd.read_csv(depmap_sample_file, index_col=0)

# %%
hgnc = [x.split(" ")[0] for x in ceres_df.columns]
ncbi_gene_id = [x.split(" ")[1].strip("()") for x in ceres_df.columns]
ncbi_gene_id
# Out:
# ['1',
#  '29974',
#  '2',
#  '144568',
#  '127550',
#  '53947',
#  '51146',
#  '8086',
#  '65985',
#  '394',
#  '395',
#  '23779',
#  '64333',
#  '396',
#  '397',
#  '398',
#  '9138',
#  '9639',
#  '55160',
#  '9826',
#  '23365',
#  '22899',
#  '27237',
#  '9828',
#  '23370',
#  '128272',
#  '9181',
#  '115557',
#  '26084',
#  '64283',
#  '50650',
#  '100271715',
#  '445328',
#  '389337',
#  '54848',
#  '84904',
#  '50649',
#  '55701',
#  '7984',
#  '9459',
#  '8874',
#  '23229',
#  '8289',
#  '57492',
#  '196528',
#  '1820',
#  '10620',
#  '138715',
#  '5926',
#  '51742',
#  '10865',
#  '84159',
#  '25820',
#  '10425',
#  '646450',
#  '400',
#  '285598',
#  '115761',
#  '392509',
#  '200894',
#  '80117',
#  '120534',
#  '644100',
#  '54622',
#  '339231',
#  '402',
#  '23568',
#  '403',
#  '10124',
#  '10123',
#  '379',
#  '26225',
#  '221079',
#  '390790',
#  '84100',
#  '23204',
#  '51329',
#  '10550',
#  ...]

# %%
ceres_df.columns
# Out:
# Index(['A1BG (1)', 'A1CF (29974)', 'A2M (2)', 'A2ML1 (144568)',
#        'A3GALT2 (127550)', 'A4GALT (53947)', 'A4GNT (51146)', 'AAAS (8086)',
#        'AACS (65985)', 'AADAC (13)',
#        ...
#        'ZWILCH (55055)', 'ZWINT (11130)', 'ZXDA (7789)', 'ZXDB (158586)',
#        'ZXDC (79364)', 'ZYG11A (440590)', 'ZYG11B (79699)', 'ZYX (7791)',
#        'ZZEF1 (23140)', 'ZZZ3 (26009)'],
#       dtype='object', length=18119)

# %%
# Clean gene name column
hgnc = [x.split(" ")[0] for x in ceres_df.columns]
ncbi_gene_id = [x.split(" ")[1].strip("()") for x in ceres_df.columns]

ceres_genes_df = (
    pd.DataFrame([hgnc, ncbi_gene_id], index=["HGNC", "NCBI"])
    .transpose()
    .sort_values(by="HGNC")
    .reset_index(drop=True)
)

# Set column names to NCBI
ceres_df.columns = ncbi_gene_id

ceres_genes_df.head(3)
# Out:
#    HGNC   NCBI
# 0  A1BG      1
# 1  A1CF  29974
# 2   A2M      2

# %%
# Merge the data
ceres_df = depmap_sample_df.merge(ceres_df, left_index=True, right_index=True, how="right")

print(ceres_df.shape)
ceres_df.head(3)
# Out:
# (789, 18143)
#            stripped_cell_line_name  \
# DepMap_ID
# ACH-000004                     HEL
# ACH-000005                 HEL9217
# ACH-000007                   LS513
#
#                                              CCLE_Name Alias  COSMICID   sex  \
# DepMap_ID
# ACH-000004      HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE   NaN  907053.0  Male
# ACH-000005  HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE   NaN       NaN  Male
# ACH-000007                       LS513_LARGE_INTESTINE   NaN  907795.0  Male
#
#            source  Achilles_n_replicates  cell_line_NNMD culture_type  \
# DepMap_ID
# ACH-000004   DSMZ                    2.0       -3.079202   Suspension
# ACH-000005   ATCC                    2.0       -2.404409   Suspension
# ACH-000007   ATCC                    2.0       -2.586708     Adherent
#
#             culture_medium  ...     55055     11130      7789    158586  \
# DepMap_ID                   ...
# ACH-000004  RPMI + 10% FBS  ... -0.124640 -0.467130       NaN       NaN
# ACH-000005  RPMI + 10% FBS  ... -0.199184 -0.411868 -0.160226 -0.066143
# ACH-000007  RPMI + 10% FBS  ... -0.094879 -0.277592 -0.051759  0.119408
#
#                79364    440590     79699      7791     23140     26009
# DepMap_ID
# ACH-000004  0.255396  0.239990 -0.408827  0.290927  0.224651 -0.135151
# ACH-000005  0.223034 -0.076115 -0.102586  0.073836  0.026112 -0.250565
# ACH-000007  0.213447 -0.010327 -0.351529  0.085902 -0.392298 -0.440062
#
# [3 rows x 18143 columns]

# %%
cell_lines = cell_health_grit_df.cell_line.unique().tolist()
assert all([x in ceres_df.stripped_cell_line_name.tolist() for x in cell_lines])

# %%
cols = ["stripped_cell_line_name"] + cell_health_grit_df._id.dropna().unique().tolist()
ceres_subset_df = (
    ceres_df.query("stripped_cell_line_name in @cell_lines")
    .loc[:, cols]
    .reset_index()
    .melt(
        id_vars=["DepMap_ID", "stripped_cell_line_name"],
        var_name="_id",
        value_name="ceres_score",
    )
)

print(ceres_subset_df.shape)
ceres_subset_df.head(3)
# Out:
# (156, 4)
#     DepMap_ID stripped_cell_line_name  _id  ceres_score
# 0  ACH-000667                   HCC44  207    -0.122035
# 1  ACH-000681                    A549  207     0.057331
# 2  ACH-000906                     ES2  207     0.107984

# %%
cell_health_results_df = cell_health_grit_df.merge(
    ceres_subset_df,
    left_on=["_id", "cell_line"],
    right_on=["_id", "stripped_cell_line_name"],
    how="left",
)

cell_health_results_df = cell_health_results_df.merge(
    (
        cell_health_results_df.groupby(["cell_line", "Metadata_gene_name"])["mean_ap"]
        .mean()
        .reset_index()
        .rename({"mean_ap": "mean_mean_ap"}, axis="columns")
    ),
    left_on=["cell_line", "Metadata_gene_name"],
    right_on=["cell_line", "Metadata_gene_name"],
    how="left",
).sort_values(by="mean_ap", ascending=False)

print(cell_health_results_df.shape)
cell_health_results_df.head(3)
# Out:
# (681, 14)
#     Metadata_gene_name Metadata_pert_name  mean_ap  p_value  n_pos_pairs  \
# 525                MYC              MYC-1      1.0   0.0001         11.0
# 398              ITGAV            ITGAV-2      1.0   0.0001         11.0
# 284              ITGAV            ITGAV-2      1.0   0.0001         11.0
#
#      n_total_pairs cell_line       barcode_control  query   _id   DepMap_ID  \
# 525          203.0       ES2       cutting_control    MYC  4609  ACH-000906
# 398          179.0      A549  perturbation_control  ITGAV  3685  ACH-000681
# 284          203.0      A549       cutting_control  ITGAV  3685  ACH-000681
#
#     stripped_cell_line_name  ceres_score  mean_mean_ap
# 525                     ES2    -1.918112           1.0
# 398                    A549    -1.051090           1.0
# 284                    A549    -1.051090           1.0

# %%
cell_health_results_df["-log10(p-value)"] = -np.log10(cell_health_results_df.p_value)
cell_health_results_df["p < 0.05"] = cell_health_results_df.p_value < 0.05

# %%
cell_line_colors = {"A549": "#861613", "ES2": "#1CADA8", "HCC44": "#2A364D"}

grit_ceres_comparison_gg = (
    gg.ggplot(cell_health_results_df, gg.aes(x="mean_ap", y="ceres_score"))
    + gg.geom_point(gg.aes(fill="cell_line"), size=1, stroke=0.2)
    + gg.scale_fill_manual(name="Cell Line", values=cell_line_colors)
    + gg.theme_bw()
    + gg.xlab("mAP")
    + gg.ylab("CERES")
    + gg.ggtitle("Cell Health")
    + gg.facet_wrap("~barcode_control", ncol=2)
    + gg.theme(strip_background=gg.element_rect(color="black", fill="#fdfff4"))
)

output_file = pathlib.Path(f"{output_dir}/cell_health_map_ceres_comparison.png")
grit_ceres_comparison_gg.save(output_file, dpi=500, height=3.5, width=6)

grit_ceres_comparison_gg
# Out:
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6 x 3.5 in image.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: figures/cell_health_map_ceres_comparison.png
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 63 rows containing missing values.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 63 rows containing missing values.
# <Figure Size: (640 x 480)>

# %%
cell_line_colors = {"A549": "#861613", "ES2": "#1CADA8", "HCC44": "#2A364D"}

grit_ceres_comparison_gg = (
    gg.ggplot(cell_health_results_df[cell_health_results_df["p < 0.05"]], gg.aes(x="mean_ap", y="ceres_score"))
    + gg.geom_point(gg.aes(fill="cell_line"), size=1, stroke=0.2)
    + gg.scale_fill_manual(name="Cell Line", values=cell_line_colors)
    + gg.theme_bw()
    + gg.xlab("mAP")
    + gg.ylab("CERES")
    + gg.ggtitle("Cell Health")
    + gg.facet_wrap("~barcode_control", ncol=2)
    + gg.theme(strip_background=gg.element_rect(color="black", fill="#fdfff4"))
)

output_file = pathlib.Path(f"{output_dir}/cell_health_map_ceres_comparison.png")
grit_ceres_comparison_gg.save(output_file, dpi=500, height=3.5, width=6)

grit_ceres_comparison_gg
# Out:
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6 x 3.5 in image.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: figures/cell_health_map_ceres_comparison.png
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 10 rows containing missing values.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 10 rows containing missing values.
# <Figure Size: (640 x 480)>

# %%
cell_line_colors = {"A549": "#861613", "ES2": "#1CADA8", "HCC44": "#2A364D"}

grit_ceres_comparison_gg = (
    gg.ggplot(cell_health_results_df, gg.aes(x="-log10(p-value)", y="ceres_score"))
    + gg.geom_point(gg.aes(fill="cell_line"), size=2, stroke=0.2, alpha=0.3)
    + gg.scale_fill_manual(name="Cell Line", values=cell_line_colors)
    + gg.theme_bw()
    + gg.xlab("-log10(p-value)")
    + gg.ylab("CERES")
    + gg.ggtitle("Cell Health")
    + gg.facet_wrap("~barcode_control", ncol=2)
    + gg.theme(strip_background=gg.element_rect(color="black", fill="#fdfff4"))
)

output_file = pathlib.Path(f"{output_dir}/cell_health_map_ceres_comparison.png")
grit_ceres_comparison_gg.save(output_file, dpi=500, height=3.5, width=6)

grit_ceres_comparison_gg
# Out:
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6 x 3.5 in image.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: figures/cell_health_map_ceres_comparison.png
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 63 rows containing missing values.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 63 rows containing missing values.
# <Figure Size: (640 x 480)>

# %%
cell_line_colors = {"A549": "#861613", "ES2": "#1CADA8", "HCC44": "#2A364D"}

grit_ceres_comparison_gg = (
    gg.ggplot(cell_health_results_df[cell_health_results_df["p < 0.05"]], gg.aes(x="-log10(p-value)", y="ceres_score"))
    + gg.geom_point(gg.aes(fill="cell_line"), size=1, stroke=0.2)
    + gg.scale_fill_manual(name="Cell Line", values=cell_line_colors)
    + gg.theme_bw()
    + gg.xlab("-log10(p-value)")
    + gg.ylab("CERES")
    + gg.ggtitle("Cell Health")
    + gg.facet_wrap("~barcode_control", ncol=2)
    + gg.theme(strip_background=gg.element_rect(color="black", fill="#fdfff4"))
)

output_file = pathlib.Path(f"{output_dir}/cell_health_map_ceres_comparison.png")
grit_ceres_comparison_gg.save(output_file, dpi=500, height=3.5, width=6)

grit_ceres_comparison_gg
# Out:
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6 x 3.5 in image.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: figures/cell_health_map_ceres_comparison.png
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 10 rows containing missing values.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 10 rows containing missing values.
# <Figure Size: (640 x 480)>

# %%
df = cell_health_results_df.copy()

df["mAP"] = df["mean_ap"]
df["p < 0.05"] = df["p_value"] < 0.05

def remove_inner_ticklabels(fig: plt.Figure):
    """
    Remove inner ticklabels from a figure.

    Parameters
    ----------
    fig : matplotlib.figure.Figure
        Figure to remove inner ticklabels from.
    """
    for ax in fig.axes:
        try:
            ax.label_outer()
        except AttributeError:
            pass


fig, axes = plt.subplots(2, 1, figsize=(5, 6), gridspec_kw={'height_ratios': [5, 1]})

mean_map = df['mAP'].mean()
fr = df['p < 0.05'].mean()
sns.scatterplot(
    ax=axes[0], 
    data=df, 
    x='mAP', 
    y='-log10(p-value)', 
    hue='p < 0.05',
    s=50
)
axes[0].set_title("Biological similarity")
axes[0].text(0.85, 0.01, f"FR: {fr:.2f}", transform=axes[0].transAxes)

axes[0].set_xlabel("")
axes[0].set_ylim(0, max(df['-log10(p-value)'])+0.1)
sns.move_legend(axes[0], "upper left")

# Second Row: KDE plots
max_kde_y = 0
mean_map = df['mAP'].mean()
for p_value in sorted(df['p < 0.05'].unique()):
    ax = sns.kdeplot(
        ax=axes[1],
        data=df[df['p < 0.05'] == p_value],
        x='mAP', 
        label=str(p_value)
    )
    max_kde_y = max(max_kde_y, max(ax.lines[-1].get_ydata()))
    axes[1].axvline(mean_map, color='grey', linestyle='--')
# axes[1].set_ylabel("")
axes[1].set_ylim(0, max_kde_y)
axes[1].text(mean_map+0.01, 0.75, f"Mean mAP: {mean_map:.2f}", transform=axes[1].transAxes)

for ax in axes.flat:
    ax.set_xlim(0, 1)  # Set x-axis limit to 0-1 for all subplots

remove_inner_ticklabels(fig)
plt.tight_layout()
plt.show()

# %%
(
    cell_health_results_df.query("ceres_score > -1.1")
    .query("mean_mean_ap > 0.5")
    .query("barcode_control == 'cutting_control'")
    .sort_values(by="ceres_score", ascending=False)
    .reset_index(drop=True)
)
# Out:
#    Metadata_gene_name Metadata_pert_name   mean_ap   p_value  n_pos_pairs  \
# 0              SLC2A2           SLC2A2-2  0.676542  0.007616          5.0
# 1               ITGAV            ITGAV-1  0.993604  0.000100         11.0
# 2               ITGAV            ITGAV-2  0.992283  0.000100         11.0
# 3               CCNE1            CCNE1-2  0.648804  0.000558         11.0
# 4               CCNE1            CCNE1-1  0.678274  0.000573         11.0
# 5               EGLN1            EGLN1-9  0.653909  0.000100         11.0
# 6               EGLN1            EGLN1-8  0.618390  0.000600         11.0
# 7                RHOA             RHOA-2  0.953455  0.000100         11.0
# 8                RHOA             RHOA-1  0.940058  0.000100         11.0
# 9               SUZ12            SUZ12-2  0.456815  0.038316         11.0
# 10              SUZ12            SUZ12-1  0.455392  0.032155         11.0
# 11              CCNE1            CCNE1-2  0.588227  0.000358         11.0
# 12              CCNE1            CCNE1-1  0.593063  0.000382         11.0
# 13              MAPK1            MAPK1-2  0.992507  0.000100         11.0
# 14              MAPK1            MAPK1-1  0.995160  0.000100         11.0
# 15               RHOA             RHOA-1  0.892169  0.000100         11.0
# 16               RHOA             RHOA-2  0.890792  0.000100         11.0
# 17               PTK2             PTK2-1  0.446015  0.005979         11.0
# 18               PTK2             PTK2-2  0.415132  0.005366         11.0
# 19            CSNK1A1          CSNK1A1-2  0.577364  0.001142         11.0
# 20            CSNK1A1          CSNK1A1-1  0.798917  0.000100         11.0
# 21               PTK2             PTK2-1  0.795141  0.000350         11.0
# 22               PTK2             PTK2-2  0.804467  0.000308         11.0
# 23               CDK2             CDK2-1  0.762032  0.001608         11.0
# 24               CDK2             CDK2-2  0.746534  0.002111         11.0
# 25            CSNK1A1          CSNK1A1-1  0.821940  0.000100         11.0
# 26            CSNK1A1          CSNK1A1-2  0.648954  0.004475         11.0
# 27               CDK2             CDK2-1  0.492962  0.001158         11.0
# 28               CDK2             CDK2-2  0.554884  0.000111         11.0
# 29             SLC2A1           SLC2A1-1  0.586614  0.058577          5.0
# 30               GPX4             GPX4-2  0.842418  0.054235         11.0
# 31               GPX4             GPX4-1  0.857434  0.045212         11.0
# 32               PTK2             PTK2-2  0.821840  0.000117         11.0
# 33               PTK2             PTK2-1  0.832778  0.000120         11.0
# 34               BRAF             BRAF-2  0.979365  0.000100          5.0
# 35               ATF4             ATF4-1  0.720042  0.000100         11.0
# 36               ATF4             ATF4-2  0.737357  0.000100         11.0
# 37              ITGAV            ITGAV-1  1.000000  0.000100         11.0
# 38              ITGAV            ITGAV-2  1.000000  0.000100         11.0
# 39              EGLN1            EGLN1-9  0.813588  0.000109         11.0
# 40              EGLN1            EGLN1-8  0.806244  0.000108         11.0
# 41              ITGAV            ITGAV-2  1.000000  0.000100         11.0
# 42              ITGAV            ITGAV-1  1.000000  0.000100         11.0
#
#     n_total_pairs cell_line  barcode_control    query    _id   DepMap_ID  \
# 0           197.0       ES2  cutting_control   SLC2A2   6514  ACH-000906
# 1           203.0       ES2  cutting_control    ITGAV   3685  ACH-000906
# 2           203.0       ES2  cutting_control    ITGAV   3685  ACH-000906
# 3           203.0     HCC44  cutting_control    CCNE1    898  ACH-000667
# 4           203.0     HCC44  cutting_control    CCNE1    898  ACH-000667
# 5           203.0     HCC44  cutting_control    EGLN1  54583  ACH-000667
# 6           203.0     HCC44  cutting_control    EGLN1  54583  ACH-000667
# 7           203.0     HCC44  cutting_control     RHOA    387  ACH-000667
# 8           203.0     HCC44  cutting_control     RHOA    387  ACH-000667
# 9           203.0     HCC44  cutting_control    SUZ12  23512  ACH-000667
# 10          203.0     HCC44  cutting_control    SUZ12  23512  ACH-000667
# 11          203.0      A549  cutting_control    CCNE1    898  ACH-000681
# 12          203.0      A549  cutting_control    CCNE1    898  ACH-000681
# 13          203.0       ES2  cutting_control    MAPK1   5594  ACH-000906
# 14          203.0       ES2  cutting_control    MAPK1   5594  ACH-000906
# 15          203.0       ES2  cutting_control     RHOA    387  ACH-000906
# 16          203.0       ES2  cutting_control     RHOA    387  ACH-000906
# 17          203.0       ES2  cutting_control     PTK2   5747  ACH-000906
# 18          203.0       ES2  cutting_control     PTK2   5747  ACH-000906
# 19          203.0      A549  cutting_control  CSNK1A1   1452  ACH-000681
# 20          203.0      A549  cutting_control  CSNK1A1   1452  ACH-000681
# 21          203.0      A549  cutting_control     PTK2   5747  ACH-000681
# 22          203.0      A549  cutting_control     PTK2   5747  ACH-000681
# 23          203.0       ES2  cutting_control     CDK2   1017  ACH-000906
# 24          203.0       ES2  cutting_control     CDK2   1017  ACH-000906
# 25          203.0     HCC44  cutting_control  CSNK1A1   1452  ACH-000667
# 26          203.0     HCC44  cutting_control  CSNK1A1   1452  ACH-000667
# 27          203.0      A549  cutting_control     CDK2   1017  ACH-000681
# 28          203.0      A549  cutting_control     CDK2   1017  ACH-000681
# 29          197.0       ES2  cutting_control   SLC2A1   6513  ACH-000906
# 30          203.0       ES2  cutting_control     GPX4   2879  ACH-000906
# 31          203.0       ES2  cutting_control     GPX4   2879  ACH-000906
# 32          203.0     HCC44  cutting_control     PTK2   5747  ACH-000667
# 33          203.0     HCC44  cutting_control     PTK2   5747  ACH-000667
# 34          197.0       ES2  cutting_control     BRAF    673  ACH-000906
# 35          203.0      A549  cutting_control     ATF4    468  ACH-000681
# 36          203.0      A549  cutting_control     ATF4    468  ACH-000681
# 37          203.0      A549  cutting_control    ITGAV   3685  ACH-000681
# 38          203.0      A549  cutting_control    ITGAV   3685  ACH-000681
# 39          203.0       ES2  cutting_control    EGLN1  54583  ACH-000906
# 40          203.0       ES2  cutting_control    EGLN1  54583  ACH-000906
# 41          203.0     HCC44  cutting_control    ITGAV   3685  ACH-000667
# 42          203.0     HCC44  cutting_control    ITGAV   3685  ACH-000667
#
#    stripped_cell_line_name  ceres_score  mean_mean_ap  -log10(p-value)  \
# 0                      ES2    -0.079741      0.741887         2.118278
# 1                      ES2    -0.215508      0.995812         4.000043
# 2                      ES2    -0.215508      0.995812         4.000043
# 3                    HCC44    -0.240077      0.671436         3.253150
# 4                    HCC44    -0.240077      0.671436         3.242096
# 5                    HCC44    -0.248523      0.631019         4.000043
# 6                    HCC44    -0.248523      0.631019         3.221892
# 7                    HCC44    -0.287301      0.937356         4.000043
# 8                    HCC44    -0.287301      0.937356         4.000043
# 9                    HCC44    -0.410438      0.503928         1.416618
# 10                   HCC44    -0.410438      0.503928         1.492750
# 11                    A549    -0.489829      0.588425         3.445756
# 12                    A549    -0.489829      0.588425         3.418187
# 13                     ES2    -0.616920      0.992935         4.000043
# 14                     ES2    -0.616920      0.992935         4.000043
# 15                     ES2    -0.726909      0.923800         4.000043
# 16                     ES2    -0.726909      0.923800         4.000043
# 17                     ES2    -0.739902      0.514287         2.223342
# 18                     ES2    -0.739902      0.514287         2.270339
# 19                    A549    -0.763007      0.639649         2.942504
# 20                    A549    -0.763007      0.639649         4.000043
# 21                    A549    -0.800656      0.831317         3.455975
# 22                    A549    -0.800656      0.831317         3.511023
# 23                     ES2    -0.835286      0.727492         2.793667
# 24                     ES2    -0.835286      0.727492         2.675532
# 25                   HCC44    -0.871167      0.677450         4.000043
# 26                   HCC44    -0.871167      0.677450         2.349250
# 27                    A549    -0.875199      0.526703         2.936210
# 28                    A549    -0.875199      0.526703         3.954286
# 29                     ES2    -0.902563      0.641459         1.232269
# 30                     ES2    -0.935900      0.861359         1.265724
# 31                     ES2    -0.935900      0.861359         1.344745
# 32                   HCC44    -0.981299      0.856377         3.933097
# 33                   HCC44    -0.981299      0.856377         3.920862
# 34                     ES2    -0.988502      0.957351         4.000043
# 35                    A549    -1.025993      0.747172         4.000043
# 36                    A549    -1.025993      0.747172         4.000043
# 37                    A549    -1.051090      1.000000         4.000043
# 38                    A549    -1.051090      1.000000         4.000043
# 39                     ES2    -1.067348      0.864793         3.962255
# 40                     ES2    -1.067348      0.864793         3.965281
# 41                   HCC44    -1.076603      1.000000         4.000043
# 42                   HCC44    -1.076603      1.000000         4.000043
#
#     p < 0.05
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29     False
# 30     False
# 31      True
# 32      True
# 33      True
# 34      True
# 35      True
# 36      True
# 37      True
# 38      True
# 39      True
# 40      True
# 41      True
# 42      True

# %%
# What are the perturbations with high grit and low ceres scores?
(
    cell_health_results_df.query("mean_mean_ap > 0.5")
    .query("ceres_score > -1")
    .query("barcode_control == 'cutting_control'")
    .sort_values(by="ceres_score")
    .reset_index(drop=True)
)
# Out:
#    Metadata_gene_name Metadata_pert_name   mean_ap   p_value  n_pos_pairs  \
# 0                BRAF             BRAF-2  0.979365  0.000100          5.0
# 1                PTK2             PTK2-2  0.821840  0.000117         11.0
# 2                PTK2             PTK2-1  0.832778  0.000120         11.0
# 3                GPX4             GPX4-1  0.857434  0.045212         11.0
# 4                GPX4             GPX4-2  0.842418  0.054235         11.0
# 5              SLC2A1           SLC2A1-1  0.586614  0.058577          5.0
# 6                CDK2             CDK2-1  0.492962  0.001158         11.0
# 7                CDK2             CDK2-2  0.554884  0.000111         11.0
# 8             CSNK1A1          CSNK1A1-2  0.648954  0.004475         11.0
# 9             CSNK1A1          CSNK1A1-1  0.821940  0.000100         11.0
# 10               CDK2             CDK2-1  0.762032  0.001608         11.0
# 11               CDK2             CDK2-2  0.746534  0.002111         11.0
# 12               PTK2             PTK2-2  0.804467  0.000308         11.0
# 13               PTK2             PTK2-1  0.795141  0.000350         11.0
# 14            CSNK1A1          CSNK1A1-2  0.577364  0.001142         11.0
# 15            CSNK1A1          CSNK1A1-1  0.798917  0.000100         11.0
# 16               PTK2             PTK2-1  0.446015  0.005979         11.0
# 17               PTK2             PTK2-2  0.415132  0.005366         11.0
# 18               RHOA             RHOA-1  0.892169  0.000100         11.0
# 19               RHOA             RHOA-2  0.890792  0.000100         11.0
# 20              MAPK1            MAPK1-2  0.992507  0.000100         11.0
# 21              MAPK1            MAPK1-1  0.995160  0.000100         11.0
# 22              CCNE1            CCNE1-1  0.593063  0.000382         11.0
# 23              CCNE1            CCNE1-2  0.588227  0.000358         11.0
# 24              SUZ12            SUZ12-2  0.456815  0.038316         11.0
# 25              SUZ12            SUZ12-1  0.455392  0.032155         11.0
# 26               RHOA             RHOA-1  0.940058  0.000100         11.0
# 27               RHOA             RHOA-2  0.953455  0.000100         11.0
# 28              EGLN1            EGLN1-8  0.618390  0.000600         11.0
# 29              EGLN1            EGLN1-9  0.653909  0.000100         11.0
# 30              CCNE1            CCNE1-2  0.648804  0.000558         11.0
# 31              CCNE1            CCNE1-1  0.678274  0.000573         11.0
# 32              ITGAV            ITGAV-2  0.992283  0.000100         11.0
# 33              ITGAV            ITGAV-1  0.993604  0.000100         11.0
# 34             SLC2A2           SLC2A2-2  0.676542  0.007616          5.0
#
#     n_total_pairs cell_line  barcode_control    query    _id   DepMap_ID  \
# 0           197.0       ES2  cutting_control     BRAF    673  ACH-000906
# 1           203.0     HCC44  cutting_control     PTK2   5747  ACH-000667
# 2           203.0     HCC44  cutting_control     PTK2   5747  ACH-000667
# 3           203.0       ES2  cutting_control     GPX4   2879  ACH-000906
# 4           203.0       ES2  cutting_control     GPX4   2879  ACH-000906
# 5           197.0       ES2  cutting_control   SLC2A1   6513  ACH-000906
# 6           203.0      A549  cutting_control     CDK2   1017  ACH-000681
# 7           203.0      A549  cutting_control     CDK2   1017  ACH-000681
# 8           203.0     HCC44  cutting_control  CSNK1A1   1452  ACH-000667
# 9           203.0     HCC44  cutting_control  CSNK1A1   1452  ACH-000667
# 10          203.0       ES2  cutting_control     CDK2   1017  ACH-000906
# 11          203.0       ES2  cutting_control     CDK2   1017  ACH-000906
# 12          203.0      A549  cutting_control     PTK2   5747  ACH-000681
# 13          203.0      A549  cutting_control     PTK2   5747  ACH-000681
# 14          203.0      A549  cutting_control  CSNK1A1   1452  ACH-000681
# 15          203.0      A549  cutting_control  CSNK1A1   1452  ACH-000681
# 16          203.0       ES2  cutting_control     PTK2   5747  ACH-000906
# 17          203.0       ES2  cutting_control     PTK2   5747  ACH-000906
# 18          203.0       ES2  cutting_control     RHOA    387  ACH-000906
# 19          203.0       ES2  cutting_control     RHOA    387  ACH-000906
# 20          203.0       ES2  cutting_control    MAPK1   5594  ACH-000906
# 21          203.0       ES2  cutting_control    MAPK1   5594  ACH-000906
# 22          203.0      A549  cutting_control    CCNE1    898  ACH-000681
# 23          203.0      A549  cutting_control    CCNE1    898  ACH-000681
# 24          203.0     HCC44  cutting_control    SUZ12  23512  ACH-000667
# 25          203.0     HCC44  cutting_control    SUZ12  23512  ACH-000667
# 26          203.0     HCC44  cutting_control     RHOA    387  ACH-000667
# 27          203.0     HCC44  cutting_control     RHOA    387  ACH-000667
# 28          203.0     HCC44  cutting_control    EGLN1  54583  ACH-000667
# 29          203.0     HCC44  cutting_control    EGLN1  54583  ACH-000667
# 30          203.0     HCC44  cutting_control    CCNE1    898  ACH-000667
# 31          203.0     HCC44  cutting_control    CCNE1    898  ACH-000667
# 32          203.0       ES2  cutting_control    ITGAV   3685  ACH-000906
# 33          203.0       ES2  cutting_control    ITGAV   3685  ACH-000906
# 34          197.0       ES2  cutting_control   SLC2A2   6514  ACH-000906
#
#    stripped_cell_line_name  ceres_score  mean_mean_ap  -log10(p-value)  \
# 0                      ES2    -0.988502      0.957351         4.000043
# 1                    HCC44    -0.981299      0.856377         3.933097
# 2                    HCC44    -0.981299      0.856377         3.920862
# 3                      ES2    -0.935900      0.861359         1.344745
# 4                      ES2    -0.935900      0.861359         1.265724
# 5                      ES2    -0.902563      0.641459         1.232269
# 6                     A549    -0.875199      0.526703         2.936210
# 7                     A549    -0.875199      0.526703         3.954286
# 8                    HCC44    -0.871167      0.677450         2.349250
# 9                    HCC44    -0.871167      0.677450         4.000043
# 10                     ES2    -0.835286      0.727492         2.793667
# 11                     ES2    -0.835286      0.727492         2.675532
# 12                    A549    -0.800656      0.831317         3.511023
# 13                    A549    -0.800656      0.831317         3.455975
# 14                    A549    -0.763007      0.639649         2.942504
# 15                    A549    -0.763007      0.639649         4.000043
# 16                     ES2    -0.739902      0.514287         2.223342
# 17                     ES2    -0.739902      0.514287         2.270339
# 18                     ES2    -0.726909      0.923800         4.000043
# 19                     ES2    -0.726909      0.923800         4.000043
# 20                     ES2    -0.616920      0.992935         4.000043
# 21                     ES2    -0.616920      0.992935         4.000043
# 22                    A549    -0.489829      0.588425         3.418187
# 23                    A549    -0.489829      0.588425         3.445756
# 24                   HCC44    -0.410438      0.503928         1.416618
# 25                   HCC44    -0.410438      0.503928         1.492750
# 26                   HCC44    -0.287301      0.937356         4.000043
# 27                   HCC44    -0.287301      0.937356         4.000043
# 28                   HCC44    -0.248523      0.631019         3.221892
# 29                   HCC44    -0.248523      0.631019         4.000043
# 30                   HCC44    -0.240077      0.671436         3.253150
# 31                   HCC44    -0.240077      0.671436         3.242096
# 32                     ES2    -0.215508      0.995812         4.000043
# 33                     ES2    -0.215508      0.995812         4.000043
# 34                     ES2    -0.079741      0.741887         2.118278
#
#     p < 0.05
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
# 5      False
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# 30      True
# 31      True
# 32      True
# 33      True
# 34      True

# %%
control_compare_df = cell_health_results_df.pivot(
    index=["Metadata_pert_name", "Metadata_gene_name", "cell_line", "ceres_score"],
    columns=["barcode_control"],
    values="mean_ap",
).reset_index(drop=False)

control_compare_df.head()
# Out:
# barcode_control Metadata_pert_name Metadata_gene_name cell_line  ceres_score  \
# 0                           AKT1-1               AKT1      A549     0.057331
# 1                           AKT1-1               AKT1       ES2     0.107984
# 2                           AKT1-1               AKT1     HCC44    -0.122035
# 3                           AKT1-2               AKT1      A549     0.057331
# 4                           AKT1-2               AKT1       ES2     0.107984
#
# barcode_control  cutting_control  perturbation_control
# 0                       0.148296              0.139382
# 1                       0.117926              0.126259
# 2                       0.236639              0.261370
# 3                       0.153893              0.133902
# 4                       0.102132              0.106171

# %%
grit_barcode_comparison_gg = (
    gg.ggplot(control_compare_df, gg.aes(x="cutting_control", y="perturbation_control"))
    + gg.geom_point(gg.aes(fill="cell_line"), size=1, stroke=0.2)
    + gg.scale_fill_manual(name="Cell Line", values=cell_line_colors)
    + gg.theme_bw()
    + gg.xlab("mAP (cutting control)")
    + gg.ylab("mAP (perturbation control (empty))")
    + gg.ggtitle("Cell health barcode control comparison")
    + gg.geom_abline(intercept=0, slope=1, linetype="dashed", color="red")
    + gg.coord_fixed()
)

output_file = pathlib.Path(f"{output_dir}/cell_health_barcode_control_comparison.png")
grit_barcode_comparison_gg.save(output_file, dpi=500, height=3.5, width=4)

grit_barcode_comparison_gg
# Out:
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 4 x 3.5 in image.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: figures/cell_health_barcode_control_comparison.png
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 33 rows containing missing values.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 33 rows containing missing values.
# <Figure Size: (640 x 480)>

# %%
control_compare_df = cell_health_results_df.pivot(
    index=["Metadata_pert_name", "Metadata_gene_name", "cell_line", "ceres_score"],
    columns=["barcode_control"],
    values="-log10(p-value)",
).reset_index(drop=False)

control_compare_df.head()

# %%
grit_barcode_comparison_gg = (
    gg.ggplot(control_compare_df, gg.aes(x="cutting_control", y="perturbation_control"))
    + gg.geom_point(gg.aes(fill="cell_line"), size=2, stroke=0.2, alpha=0.3)
    + gg.scale_fill_manual(name="Cell Line", values=cell_line_colors)
    + gg.theme_bw()
    + gg.xlab("-log10(p-value) (cutting control)")
    + gg.ylab("-log10(p-value) (perturbation control (empty))")
    # + gg.ggtitle("Cell health barcode control comparison")
    + gg.geom_abline(intercept=0, slope=1, linetype="dashed", color="red")
    + gg.coord_fixed()
)

output_file = pathlib.Path(f"{output_dir}/cell_health_barcode_control_comparison.png")
grit_barcode_comparison_gg.save(output_file, dpi=500, height=3.5, width=4)

grit_barcode_comparison_gg
# Out:
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 4 x 3.5 in image.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: figures/cell_health_barcode_control_comparison.png
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 33 rows containing missing values.
# /dgx1nas1/storage/data/akalinin/miniconda3/envs/map_benchmark/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 33 rows containing missing values.
# <Figure Size: (640 x 480)>
